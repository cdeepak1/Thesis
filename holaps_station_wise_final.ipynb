# %%
import xarray as xr
import pandas as pd
import glob
import os
import numpy as np
import re

def create_station_csvs_final():
    """Final working version"""
    
    netcdf_folder = r"C:\Deepak\HOLAPS\monthly"
    stations_csv = "plot_sites_coordinates2.csv"
    output_folder = "station_data1"
    
    os.makedirs(output_folder, exist_ok=True)
    stations_df = pd.read_csv(stations_csv)
    
    for _, station in stations_df.iterrows():
        station_id = station['SITE_ID']
        station_lat = station['LATITUDE']
        station_lon = station['LONGITUDE']
        
        print(f"Processing station: {station_id}")
        all_station_data = []
        
        # Get all NetCDF files
        all_nc_files = glob.glob(os.path.join(netcdf_folder, "*.nc"))
        print(f"  Found {len(all_nc_files)} NetCDF files")
        
        for file_path in all_nc_files:
            try:
                filename = os.path.basename(file_path)
                
                # Extract year and variable
                year_match = re.search(r'(\d{4})', filename)
                var_match = re.search(r'HOLAPS-([A-Za-z0-9]+)-Europe', filename)
                
                if not year_match or not var_match:
                    continue
                
                year = int(year_match.group(1))
                var = var_match.group(1)
                
                print(f"  Reading {filename}")
                ds = xr.open_dataset(file_path)
                
                # Use nearest neighbor selection
                closest_data = ds.sel(
                    latitude=station_lat,
                    longitude=station_lon,
                    method='nearest'
                )
                
                # Get data variable (exclude bounds variables)
                data_vars = [v for v in ds.data_vars.keys() if 'bnds' not in v]
                if not data_vars:
                    ds.close()
                    continue
                
                data_var = data_vars[0]
                
                # Extract data - handle different data shapes
                data_values = closest_data[data_var]
                
                # Convert to numpy array and ensure it's 1D
                if data_values.ndim == 0:  # Scalar
                    data_values = np.array([data_values.values])
                else:  # Array
                    data_values = data_values.values
                
                # Flatten if needed to get 1D time series
                if data_values.ndim > 1:
                    data_values = data_values.flatten()
                
                time_size = len(data_values)
                print(f"    Extracted {time_size} time steps for {var} {year}")
                
                for time_idx, value in enumerate(data_values):
                    if not pd.isna(value):
                        # Handle the 13-month issue: skip first if 13 months
                        if time_size == 13 and time_idx == 0:
                            continue  # Skip first month
                        
                        actual_month = time_idx + 1 if time_size != 13 else time_idx
                        
                        all_station_data.append({
                            'station_id': station_id,
                            'year': year,
                            'month': actual_month,
                            'variable': var,
                            'value': float(value),
                            'latitude': station_lat,
                            'longitude': station_lon
                        })
                
                ds.close()
                
            except Exception as e:
                print(f"Error with {file_path}: {e}")
                continue
        
        # Save station data
        if all_station_data:
            df = pd.DataFrame(all_station_data)
            
            try:
                df_wide = df.pivot_table(
                    index=['station_id', 'year', 'month', 'latitude', 'longitude'],
                    columns='variable', 
                    values='value'
                ).reset_index()
                
                output_file = os.path.join(output_folder, f"{station_id}_all_variables.csv")
                df_wide.to_csv(output_file, index=False)
                print(f"✓ Saved: {output_file} with {len(df_wide)} records")
                
                # Show summary
                years = df_wide['year'].unique()
                print(f"  Years: {len(years)} ({min(years)}-{max(years)})")
                variables = [col for col in df_wide.columns if col not in ['station_id', 'year', 'month', 'latitude', 'longitude']]
                print(f"  Variables: {variables}")
                
            except Exception as e:
                print(f"Error creating wide format: {e}")
        else:
            print(f"✗ No data found for station {station_id}")
        
        print()

# Run the final version
create_station_csvs_final()
# Out:
# Processing station: AT-Neu
#   Found 260 NetCDF files
#   Reading HOLAPS-GHF-Europe-2001_monthly.nc
#     Extracted 13 time steps for GHF 2001
#   Reading HOLAPS-GHF-Europe-2002_monthly.nc
#     Extracted 13 time steps for GHF 2002
#   Reading HOLAPS-GHF-Europe-2003_monthly.nc
#     Extracted 13 time steps for GHF 2003
#   Reading HOLAPS-GHF-Europe-2004_monthly.nc
#     Extracted 13 time steps for GHF 2004
#   Reading HOLAPS-GHF-Europe-2005_monthly.nc
#     Extracted 13 time steps for GHF 2005
#   Reading HOLAPS-GHF-Europe-2006_monthly.nc
#     Extracted 13 time steps for GHF 2006
#   Reading HOLAPS-GHF-Europe-2007_monthly.nc
#     Extracted 13 time steps for GHF 2007
#   Reading HOLAPS-GHF-Europe-2008_monthly.nc
#     Extracted 13 time steps for GHF 2008
#   Reading HOLAPS-GHF-Europe-2009_monthly.nc
#     Extracted 13 time steps for GHF 2009
#   Reading HOLAPS-GHF-Europe-2010_monthly.nc
#     Extracted 13 time steps for GHF 2010
#   Reading HOLAPS-GHF-Europe-2011_monthly.nc
#     Extracted 13 time steps for GHF 2011
#   Reading HOLAPS-GHF-Europe-2012_monthly.nc
#     Extracted 13 time steps for GHF 2012
#   Reading HOLAPS-GHF-Europe-2013_monthly.nc
#     Extracted 13 time steps for GHF 2013
#   Reading HOLAPS-GHF-Europe-2014_monthly.nc
#     Extracted 13 time steps for GHF 2014
#   Reading HOLAPS-GHF-Europe-2015_monthly.nc
#     Extracted 13 time steps for GHF 2015
#   Reading HOLAPS-GHF-Europe-2016_monthly.nc
#     Extracted 13 time steps for GHF 2016
#   Reading HOLAPS-GHF-Europe-2017_monthly.nc
#     Extracted 13 time steps for GHF 2017
#   Reading HOLAPS-GHF-Europe-2018_monthly.nc
#     Extracted 13 time steps for GHF 2018
#   Reading HOLAPS-GHF-Europe-2019_monthly.nc
#     Extracted 13 time steps for GHF 2019
#   Reading HOLAPS-GHF-Europe-2020_monthly.nc
#     Extracted 13 time steps for GHF 2020
#   Reading HOLAPS-H-Europe-2001_monthly.nc
#     Extracted 13 time steps for H 2001
#   Reading HOLAPS-H-Europe-2002_monthly.nc
#     Extracted 13 time steps for H 2002
#   Reading HOLAPS-H-Europe-2003_monthly.nc
#     Extracted 13 time steps for H 2003
#   Reading HOLAPS-H-Europe-2004_monthly.nc
#     Extracted 13 time steps for H 2004
#   Reading HOLAPS-H-Europe-2005_monthly.nc
#     Extracted 13 time steps for H 2005
#   Reading HOLAPS-H-Europe-2006_monthly.nc
#     Extracted 13 time steps for H 2006
#   Reading HOLAPS-H-Europe-2007_monthly.nc
#     Extracted 13 time steps for H 2007
#   Reading HOLAPS-H-Europe-2008_monthly.nc
#     Extracted 13 time steps for H 2008
#   Reading HOLAPS-H-Europe-2009_monthly.nc
#     Extracted 13 time steps for H 2009
#   Reading HOLAPS-H-Europe-2010_monthly.nc
#     Extracted 13 time steps for H 2010
#   Reading HOLAPS-H-Europe-2011_monthly.nc
#     Extracted 13 time steps for H 2011
#   Reading HOLAPS-H-Europe-2012_monthly.nc
#     Extracted 13 time steps for H 2012
#   Reading HOLAPS-H-Europe-2013_monthly.nc
#     Extracted 13 time steps for H 2013
#   Reading HOLAPS-H-Europe-2014_monthly.nc
#     Extracted 13 time steps for H 2014
#   Reading HOLAPS-H-Europe-2015_monthly.nc
#     Extracted 13 time steps for H 2015
#   Reading HOLAPS-H-Europe-2016_monthly.nc
#     Extracted 13 time steps for H 2016
#   Reading HOLAPS-H-Europe-2017_monthly.nc
#     Extracted 13 time steps for H 2017
#   Reading HOLAPS-H-Europe-2018_monthly.nc
#     Extracted 13 time steps for H 2018
#   Reading HOLAPS-H-Europe-2019_monthly.nc
#     Extracted 13 time steps for H 2019
#   Reading HOLAPS-H-Europe-2020_monthly.nc
#     Extracted 13 time steps for H 2020
#   Reading HOLAPS-LE-Europe-2001_monthly.nc
#     Extracted 13 time steps for LE 2001
#   Reading HOLAPS-LE-Europe-2002_monthly.nc
#     Extracted 13 time steps for LE 2002
#   Reading HOLAPS-LE-Europe-2003_monthly.nc
#     Extracted 13 time steps for LE 2003
#   Reading HOLAPS-LE-Europe-2004_monthly.nc
#     Extracted 13 time steps for LE 2004
#   Reading HOLAPS-LE-Europe-2005_monthly.nc
#     Extracted 13 time steps for LE 2005
#   Reading HOLAPS-LE-Europe-2006_monthly.nc
#     Extracted 13 time steps for LE 2006
#   Reading HOLAPS-LE-Europe-2007_monthly.nc
#     Extracted 13 time steps for LE 2007
#   Reading HOLAPS-LE-Europe-2008_monthly.nc
#     Extracted 13 time steps for LE 2008
#   Reading HOLAPS-LE-Europe-2009_monthly.nc
#     Extracted 13 time steps for LE 2009
#   Reading HOLAPS-LE-Europe-2010_monthly.nc
#     Extracted 13 time steps for LE 2010
#   Reading HOLAPS-LE-Europe-2011_monthly.nc
#     Extracted 13 time steps for LE 2011
#   Reading HOLAPS-LE-Europe-2012_monthly.nc
#     Extracted 13 time steps for LE 2012
#   Reading HOLAPS-LE-Europe-2013_monthly.nc
#     Extracted 13 time steps for LE 2013
#   Reading HOLAPS-LE-Europe-2014_monthly.nc
#     Extracted 13 time steps for LE 2014
#   Reading HOLAPS-LE-Europe-2015_monthly.nc
#     Extracted 13 time steps for LE 2015
#   Reading HOLAPS-LE-Europe-2016_monthly.nc
#     Extracted 13 time steps for LE 2016
#   Reading HOLAPS-LE-Europe-2017_monthly.nc
#     Extracted 13 time steps for LE 2017
#   Reading HOLAPS-LE-Europe-2018_monthly.nc
#     Extracted 13 time steps for LE 2018
#   Reading HOLAPS-LE-Europe-2019_monthly.nc
#     Extracted 13 time steps for LE 2019
#   Reading HOLAPS-LE-Europe-2020_monthly.nc
#     Extracted 13 time steps for LE 2020
#   Reading HOLAPS-rain-Europe-2001_monthly.nc
#     Extracted 13 time steps for rain 2001
#   Reading HOLAPS-rain-Europe-2002_monthly.nc
#     Extracted 13 time steps for rain 2002
#   Reading HOLAPS-rain-Europe-2003_monthly.nc
#     Extracted 13 time steps for rain 2003
#   Reading HOLAPS-rain-Europe-2004_monthly.nc
#     Extracted 13 time steps for rain 2004
#   Reading HOLAPS-rain-Europe-2005_monthly.nc
#     Extracted 13 time steps for rain 2005
#   Reading HOLAPS-rain-Europe-2006_monthly.nc
#     Extracted 13 time steps for rain 2006
#   Reading HOLAPS-rain-Europe-2007_monthly.nc
#     Extracted 13 time steps for rain 2007
#   Reading HOLAPS-rain-Europe-2008_monthly.nc
#     Extracted 13 time steps for rain 2008
#   Reading HOLAPS-rain-Europe-2009_monthly.nc
#     Extracted 13 time steps for rain 2009
#   Reading HOLAPS-rain-Europe-2010_monthly.nc
#     Extracted 13 time steps for rain 2010
#   Reading HOLAPS-rain-Europe-2011_monthly.nc
#     Extracted 13 time steps for rain 2011
#   Reading HOLAPS-rain-Europe-2012_monthly.nc
#     Extracted 13 time steps for rain 2012
#   Reading HOLAPS-rain-Europe-2013_monthly.nc
#     Extracted 13 time steps for rain 2013
#   Reading HOLAPS-rain-Europe-2014_monthly.nc
#     Extracted 13 time steps for rain 2014
#   Reading HOLAPS-rain-Europe-2015_monthly.nc
#     Extracted 13 time steps for rain 2015
#   Reading HOLAPS-rain-Europe-2016_monthly.nc
#     Extracted 13 time steps for rain 2016
#   Reading HOLAPS-rain-Europe-2017_monthly.nc
#     Extracted 13 time steps for rain 2017
#   Reading HOLAPS-rain-Europe-2018_monthly.nc
#     Extracted 13 time steps for rain 2018
#   Reading HOLAPS-rain-Europe-2019_monthly.nc
#     Extracted 13 time steps for rain 2019
#   Reading HOLAPS-rain-Europe-2020_monthly.nc
#     Extracted 13 time steps for rain 2020
#   Reading HOLAPS-Rn-Europe-2001_monthly.nc
#     Extracted 13 time steps for Rn 2001
#   Reading HOLAPS-Rn-Europe-2002_monthly.nc
#     Extracted 13 time steps for Rn 2002
#   Reading HOLAPS-Rn-Europe-2003_monthly.nc
#     Extracted 13 time steps for Rn 2003
#   Reading HOLAPS-Rn-Europe-2004_monthly.nc
#     Extracted 13 time steps for Rn 2004
#   Reading HOLAPS-Rn-Europe-2005_monthly.nc
#     Extracted 13 time steps for Rn 2005
#   Reading HOLAPS-Rn-Europe-2006_monthly.nc
#     Extracted 13 time steps for Rn 2006
#   Reading HOLAPS-Rn-Europe-2007_monthly.nc
#     Extracted 13 time steps for Rn 2007
#   Reading HOLAPS-Rn-Europe-2008_monthly.nc
#     Extracted 13 time steps for Rn 2008
#   Reading HOLAPS-Rn-Europe-2009_monthly.nc
#     Extracted 13 time steps for Rn 2009
#   Reading HOLAPS-Rn-Europe-2010_monthly.nc
#     Extracted 13 time steps for Rn 2010
#   Reading HOLAPS-Rn-Europe-2011_monthly.nc
#     Extracted 13 time steps for Rn 2011
#   Reading HOLAPS-Rn-Europe-2012_monthly.nc
#     Extracted 13 time steps for Rn 2012
#   Reading HOLAPS-Rn-Europe-2013_monthly.nc
#     Extracted 13 time steps for Rn 2013
#   Reading HOLAPS-Rn-Europe-2014_monthly.nc
#     Extracted 13 time steps for Rn 2014
#   Reading HOLAPS-Rn-Europe-2015_monthly.nc
#     Extracted 13 time steps for Rn 2015
#   Reading HOLAPS-Rn-Europe-2016_monthly.nc
#     Extracted 13 time steps for Rn 2016
#   Reading HOLAPS-Rn-Europe-2017_monthly.nc
#     Extracted 13 time steps for Rn 2017
#   Reading HOLAPS-Rn-Europe-2018_monthly.nc
#     Extracted 13 time steps for Rn 2018
#   Reading HOLAPS-Rn-Europe-2019_monthly.nc
#     Extracted 13 time steps for Rn 2019
#   Reading HOLAPS-Rn-Europe-2020_monthly.nc
#     Extracted 13 time steps for Rn 2020
#   Reading HOLAPS-sm1-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm1 2001
#   Reading HOLAPS-sm1-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm1 2002
#   Reading HOLAPS-sm1-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm1 2003
#   Reading HOLAPS-sm1-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm1 2004
#   Reading HOLAPS-sm1-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm1 2005
#   Reading HOLAPS-sm1-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm1 2006
#   Reading HOLAPS-sm1-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm1 2007
#   Reading HOLAPS-sm1-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm1 2008
#   Reading HOLAPS-sm1-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm1 2009
#   Reading HOLAPS-sm1-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm1 2010
#   Reading HOLAPS-sm1-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm1 2011
#   Reading HOLAPS-sm1-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm1 2012
#   Reading HOLAPS-sm1-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm1 2013
#   Reading HOLAPS-sm1-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm1 2014
#   Reading HOLAPS-sm1-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm1 2015
#   Reading HOLAPS-sm1-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm1 2016
#   Reading HOLAPS-sm1-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm1 2017
#   Reading HOLAPS-sm1-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm1 2018
#   Reading HOLAPS-sm1-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm1 2019
#   Reading HOLAPS-sm1-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm1 2020
#   Reading HOLAPS-sm2-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm2 2001
#   Reading HOLAPS-sm2-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm2 2002
#   Reading HOLAPS-sm2-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm2 2003
#   Reading HOLAPS-sm2-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm2 2004
#   Reading HOLAPS-sm2-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm2 2005
#   Reading HOLAPS-sm2-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm2 2006
#   Reading HOLAPS-sm2-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm2 2007
#   Reading HOLAPS-sm2-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm2 2008
#   Reading HOLAPS-sm2-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm2 2009
#   Reading HOLAPS-sm2-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm2 2010
#   Reading HOLAPS-sm2-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm2 2011
#   Reading HOLAPS-sm2-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm2 2012
#   Reading HOLAPS-sm2-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm2 2013
#   Reading HOLAPS-sm2-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm2 2014
#   Reading HOLAPS-sm2-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm2 2015
#   Reading HOLAPS-sm2-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm2 2016
#   Reading HOLAPS-sm2-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm2 2017
#   Reading HOLAPS-sm2-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm2 2018
#   Reading HOLAPS-sm2-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm2 2019
#   Reading HOLAPS-sm2-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm2 2020
#   Reading HOLAPS-sm3-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm3 2001
#   Reading HOLAPS-sm3-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm3 2002
#   Reading HOLAPS-sm3-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm3 2003
#   Reading HOLAPS-sm3-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm3 2004
#   Reading HOLAPS-sm3-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm3 2005
#   Reading HOLAPS-sm3-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm3 2006
#   Reading HOLAPS-sm3-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm3 2007
#   Reading HOLAPS-sm3-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm3 2008
#   Reading HOLAPS-sm3-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm3 2009
#   Reading HOLAPS-sm3-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm3 2010
#   Reading HOLAPS-sm3-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm3 2011
#   Reading HOLAPS-sm3-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm3 2012
#   Reading HOLAPS-sm3-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm3 2013
#   Reading HOLAPS-sm3-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm3 2014
#   Reading HOLAPS-sm3-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm3 2015
#   Reading HOLAPS-sm3-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm3 2016
#   Reading HOLAPS-sm3-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm3 2017
#   Reading HOLAPS-sm3-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm3 2018
#   Reading HOLAPS-sm3-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm3 2019
#   Reading HOLAPS-sm3-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm3 2020
#   Reading HOLAPS-sm4-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm4 2001
#   Reading HOLAPS-sm4-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm4 2002
#   Reading HOLAPS-sm4-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm4 2003
#   Reading HOLAPS-sm4-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm4 2004
#   Reading HOLAPS-sm4-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm4 2005
#   Reading HOLAPS-sm4-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm4 2006
#   Reading HOLAPS-sm4-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm4 2007
#   Reading HOLAPS-sm4-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm4 2008
#   Reading HOLAPS-sm4-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm4 2009
#   Reading HOLAPS-sm4-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm4 2010
#   Reading HOLAPS-sm4-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm4 2011
#   Reading HOLAPS-sm4-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm4 2012
#   Reading HOLAPS-sm4-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm4 2013
#   Reading HOLAPS-sm4-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm4 2014
#   Reading HOLAPS-sm4-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm4 2015
#   Reading HOLAPS-sm4-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm4 2016
#   Reading HOLAPS-sm4-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm4 2017
#   Reading HOLAPS-sm4-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm4 2018
#   Reading HOLAPS-sm4-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm4 2019
#   Reading HOLAPS-sm4-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm4 2020
#   Reading HOLAPS-sm5-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm5 2001
#   Reading HOLAPS-sm5-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm5 2002
#   Reading HOLAPS-sm5-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm5 2003
#   Reading HOLAPS-sm5-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm5 2004
#   Reading HOLAPS-sm5-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm5 2005
#   Reading HOLAPS-sm5-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm5 2006
#   Reading HOLAPS-sm5-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm5 2007
#   Reading HOLAPS-sm5-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm5 2008
#   Reading HOLAPS-sm5-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm5 2009
#   Reading HOLAPS-sm5-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm5 2010
#   Reading HOLAPS-sm5-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm5 2011
#   Reading HOLAPS-sm5-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm5 2012
#   Reading HOLAPS-sm5-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm5 2013
#   Reading HOLAPS-sm5-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm5 2014
#   Reading HOLAPS-sm5-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm5 2015
#   Reading HOLAPS-sm5-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm5 2016
#   Reading HOLAPS-sm5-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm5 2017
#   Reading HOLAPS-sm5-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm5 2018
#   Reading HOLAPS-sm5-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm5 2019
#   Reading HOLAPS-sm5-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm5 2020
#   Reading HOLAPS-Ta-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ta 2001
#   Reading HOLAPS-Ta-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ta 2002
#   Reading HOLAPS-Ta-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ta 2003
#   Reading HOLAPS-Ta-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ta 2004
#   Reading HOLAPS-Ta-Europe-2005_monthly.nc
#     Extracted 13 time steps for Ta 2005
#   Reading HOLAPS-Ta-Europe-2006_monthly.nc
#     Extracted 13 time steps for Ta 2006
#   Reading HOLAPS-Ta-Europe-2007_monthly.nc
#     Extracted 13 time steps for Ta 2007
#   Reading HOLAPS-Ta-Europe-2008_monthly.nc
#     Extracted 13 time steps for Ta 2008
#   Reading HOLAPS-Ta-Europe-2009_monthly.nc
#     Extracted 13 time steps for Ta 2009
#   Reading HOLAPS-Ta-Europe-2010_monthly.nc
#     Extracted 13 time steps for Ta 2010
#   Reading HOLAPS-Ta-Europe-2011_monthly.nc
#     Extracted 13 time steps for Ta 2011
#   Reading HOLAPS-Ta-Europe-2012_monthly.nc
#     Extracted 13 time steps for Ta 2012
#   Reading HOLAPS-Ta-Europe-2013_monthly.nc
#     Extracted 13 time steps for Ta 2013
#   Reading HOLAPS-Ta-Europe-2014_monthly.nc
#     Extracted 13 time steps for Ta 2014
#   Reading HOLAPS-Ta-Europe-2015_monthly.nc
#     Extracted 13 time steps for Ta 2015
#   Reading HOLAPS-Ta-Europe-2016_monthly.nc
#     Extracted 13 time steps for Ta 2016
#   Reading HOLAPS-Ta-Europe-2017_monthly.nc
#     Extracted 13 time steps for Ta 2017
#   Reading HOLAPS-Ta-Europe-2018_monthly.nc
#     Extracted 13 time steps for Ta 2018
#   Reading HOLAPS-Ta-Europe-2019_monthly.nc
#     Extracted 13 time steps for Ta 2019
#   Reading HOLAPS-Ta-Europe-2020_monthly.nc
#     Extracted 13 time steps for Ta 2020
#   Reading HOLAPS-Td-Europe-2001_monthly.nc
#     Extracted 13 time steps for Td 2001
#   Reading HOLAPS-Td-Europe-2002_monthly.nc
#     Extracted 13 time steps for Td 2002
#   Reading HOLAPS-Td-Europe-2003_monthly.nc
#     Extracted 13 time steps for Td 2003
#   Reading HOLAPS-Td-Europe-2004_monthly.nc
#     Extracted 13 time steps for Td 2004
#   Reading HOLAPS-Td-Europe-2005_monthly.nc
#     Extracted 13 time steps for Td 2005
#   Reading HOLAPS-Td-Europe-2006_monthly.nc
#     Extracted 13 time steps for Td 2006
#   Reading HOLAPS-Td-Europe-2007_monthly.nc
#     Extracted 13 time steps for Td 2007
#   Reading HOLAPS-Td-Europe-2008_monthly.nc
#     Extracted 13 time steps for Td 2008
#   Reading HOLAPS-Td-Europe-2009_monthly.nc
#     Extracted 13 time steps for Td 2009
#   Reading HOLAPS-Td-Europe-2010_monthly.nc
#     Extracted 13 time steps for Td 2010
#   Reading HOLAPS-Td-Europe-2011_monthly.nc
#     Extracted 13 time steps for Td 2011
#   Reading HOLAPS-Td-Europe-2012_monthly.nc
#     Extracted 13 time steps for Td 2012
#   Reading HOLAPS-Td-Europe-2013_monthly.nc
#     Extracted 13 time steps for Td 2013
#   Reading HOLAPS-Td-Europe-2014_monthly.nc
#     Extracted 13 time steps for Td 2014
#   Reading HOLAPS-Td-Europe-2015_monthly.nc
#     Extracted 13 time steps for Td 2015
#   Reading HOLAPS-Td-Europe-2016_monthly.nc
#     Extracted 13 time steps for Td 2016
#   Reading HOLAPS-Td-Europe-2017_monthly.nc
#     Extracted 13 time steps for Td 2017
#   Reading HOLAPS-Td-Europe-2018_monthly.nc
#     Extracted 13 time steps for Td 2018
#   Reading HOLAPS-Td-Europe-2019_monthly.nc
#     Extracted 13 time steps for Td 2019
#   Reading HOLAPS-Td-Europe-2020_monthly.nc
#     Extracted 13 time steps for Td 2020
#   Reading HOLAPS-Ts-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ts 2001
#   Reading HOLAPS-Ts-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ts 2002
#   Reading HOLAPS-Ts-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ts 2003
#   Reading HOLAPS-Ts-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ts 2004
#   Reading HOLAPS-Ts-Europe-2005_monthly.nc
#     Extracted 13 time steps for Ts 2005
#   Reading HOLAPS-Ts-Europe-2006_monthly.nc
#     Extracted 13 time steps for Ts 2006
#   Reading HOLAPS-Ts-Europe-2007_monthly.nc
#     Extracted 13 time steps for Ts 2007
#   Reading HOLAPS-Ts-Europe-2008_monthly.nc
#     Extracted 13 time steps for Ts 2008
#   Reading HOLAPS-Ts-Europe-2009_monthly.nc
#     Extracted 13 time steps for Ts 2009
#   Reading HOLAPS-Ts-Europe-2010_monthly.nc
#     Extracted 13 time steps for Ts 2010
#   Reading HOLAPS-Ts-Europe-2011_monthly.nc
#     Extracted 13 time steps for Ts 2011
#   Reading HOLAPS-Ts-Europe-2012_monthly.nc
#     Extracted 13 time steps for Ts 2012
#   Reading HOLAPS-Ts-Europe-2013_monthly.nc
#     Extracted 13 time steps for Ts 2013
#   Reading HOLAPS-Ts-Europe-2014_monthly.nc
#     Extracted 13 time steps for Ts 2014
#   Reading HOLAPS-Ts-Europe-2015_monthly.nc
#     Extracted 13 time steps for Ts 2015
#   Reading HOLAPS-Ts-Europe-2016_monthly.nc
#     Extracted 13 time steps for Ts 2016
#   Reading HOLAPS-Ts-Europe-2017_monthly.nc
#     Extracted 13 time steps for Ts 2017
#   Reading HOLAPS-Ts-Europe-2018_monthly.nc
#     Extracted 13 time steps for Ts 2018
#   Reading HOLAPS-Ts-Europe-2019_monthly.nc
#     Extracted 13 time steps for Ts 2019
#   Reading HOLAPS-Ts-Europe-2020_monthly.nc
#     Extracted 13 time steps for Ts 2020
# ✓ Saved: station_data1\AT-Neu_all_variables.csv with 240 records
#   Years: 20 (2001-2020)
#   Variables: ['GHF', 'H', 'LE', 'Rn', 'Ta', 'Td', 'Ts', 'rain', 'sm1', 'sm2', 'sm3', 'sm4', 'sm5']
#
# Processing station: BE-Bra
#   Found 260 NetCDF files
#   Reading HOLAPS-GHF-Europe-2001_monthly.nc
#     Extracted 13 time steps for GHF 2001
#   Reading HOLAPS-GHF-Europe-2002_monthly.nc
#     Extracted 13 time steps for GHF 2002
#   Reading HOLAPS-GHF-Europe-2003_monthly.nc
#     Extracted 13 time steps for GHF 2003
#   Reading HOLAPS-GHF-Europe-2004_monthly.nc
#     Extracted 13 time steps for GHF 2004
#   Reading HOLAPS-GHF-Europe-2005_monthly.nc
#     Extracted 13 time steps for GHF 2005
#   Reading HOLAPS-GHF-Europe-2006_monthly.nc
#     Extracted 13 time steps for GHF 2006
#   Reading HOLAPS-GHF-Europe-2007_monthly.nc
#     Extracted 13 time steps for GHF 2007
#   Reading HOLAPS-GHF-Europe-2008_monthly.nc
#     Extracted 13 time steps for GHF 2008
#   Reading HOLAPS-GHF-Europe-2009_monthly.nc
#     Extracted 13 time steps for GHF 2009
#   Reading HOLAPS-GHF-Europe-2010_monthly.nc
#     Extracted 13 time steps for GHF 2010
#   Reading HOLAPS-GHF-Europe-2011_monthly.nc
#     Extracted 13 time steps for GHF 2011
#   Reading HOLAPS-GHF-Europe-2012_monthly.nc
#     Extracted 13 time steps for GHF 2012
#   Reading HOLAPS-GHF-Europe-2013_monthly.nc
#     Extracted 13 time steps for GHF 2013
#   Reading HOLAPS-GHF-Europe-2014_monthly.nc
#     Extracted 13 time steps for GHF 2014
#   Reading HOLAPS-GHF-Europe-2015_monthly.nc
#     Extracted 13 time steps for GHF 2015
#   Reading HOLAPS-GHF-Europe-2016_monthly.nc
#     Extracted 13 time steps for GHF 2016
#   Reading HOLAPS-GHF-Europe-2017_monthly.nc
#     Extracted 13 time steps for GHF 2017
#   Reading HOLAPS-GHF-Europe-2018_monthly.nc
#     Extracted 13 time steps for GHF 2018
#   Reading HOLAPS-GHF-Europe-2019_monthly.nc
#     Extracted 13 time steps for GHF 2019
#   Reading HOLAPS-GHF-Europe-2020_monthly.nc
#     Extracted 13 time steps for GHF 2020
#   Reading HOLAPS-H-Europe-2001_monthly.nc
#     Extracted 13 time steps for H 2001
#   Reading HOLAPS-H-Europe-2002_monthly.nc
#     Extracted 13 time steps for H 2002
#   Reading HOLAPS-H-Europe-2003_monthly.nc
#     Extracted 13 time steps for H 2003
#   Reading HOLAPS-H-Europe-2004_monthly.nc
#     Extracted 13 time steps for H 2004
#   Reading HOLAPS-H-Europe-2005_monthly.nc
#     Extracted 13 time steps for H 2005
#   Reading HOLAPS-H-Europe-2006_monthly.nc
#     Extracted 13 time steps for H 2006
#   Reading HOLAPS-H-Europe-2007_monthly.nc
#     Extracted 13 time steps for H 2007
#   Reading HOLAPS-H-Europe-2008_monthly.nc
#     Extracted 13 time steps for H 2008
#   Reading HOLAPS-H-Europe-2009_monthly.nc
#     Extracted 13 time steps for H 2009
#   Reading HOLAPS-H-Europe-2010_monthly.nc
#     Extracted 13 time steps for H 2010
#   Reading HOLAPS-H-Europe-2011_monthly.nc
#     Extracted 13 time steps for H 2011
#   Reading HOLAPS-H-Europe-2012_monthly.nc
#     Extracted 13 time steps for H 2012
#   Reading HOLAPS-H-Europe-2013_monthly.nc
#     Extracted 13 time steps for H 2013
#   Reading HOLAPS-H-Europe-2014_monthly.nc
#     Extracted 13 time steps for H 2014
#   Reading HOLAPS-H-Europe-2015_monthly.nc
#     Extracted 13 time steps for H 2015
#   Reading HOLAPS-H-Europe-2016_monthly.nc
#     Extracted 13 time steps for H 2016
#   Reading HOLAPS-H-Europe-2017_monthly.nc
#     Extracted 13 time steps for H 2017
#   Reading HOLAPS-H-Europe-2018_monthly.nc
#     Extracted 13 time steps for H 2018
#   Reading HOLAPS-H-Europe-2019_monthly.nc
#     Extracted 13 time steps for H 2019
#   Reading HOLAPS-H-Europe-2020_monthly.nc
#     Extracted 13 time steps for H 2020
#   Reading HOLAPS-LE-Europe-2001_monthly.nc
#     Extracted 13 time steps for LE 2001
#   Reading HOLAPS-LE-Europe-2002_monthly.nc
#     Extracted 13 time steps for LE 2002
#   Reading HOLAPS-LE-Europe-2003_monthly.nc
#     Extracted 13 time steps for LE 2003
#   Reading HOLAPS-LE-Europe-2004_monthly.nc
#     Extracted 13 time steps for LE 2004
#   Reading HOLAPS-LE-Europe-2005_monthly.nc
#     Extracted 13 time steps for LE 2005
#   Reading HOLAPS-LE-Europe-2006_monthly.nc
#     Extracted 13 time steps for LE 2006
#   Reading HOLAPS-LE-Europe-2007_monthly.nc
#     Extracted 13 time steps for LE 2007
#   Reading HOLAPS-LE-Europe-2008_monthly.nc
#     Extracted 13 time steps for LE 2008
#   Reading HOLAPS-LE-Europe-2009_monthly.nc
#     Extracted 13 time steps for LE 2009
#   Reading HOLAPS-LE-Europe-2010_monthly.nc
#     Extracted 13 time steps for LE 2010
#   Reading HOLAPS-LE-Europe-2011_monthly.nc
#     Extracted 13 time steps for LE 2011
#   Reading HOLAPS-LE-Europe-2012_monthly.nc
#     Extracted 13 time steps for LE 2012
#   Reading HOLAPS-LE-Europe-2013_monthly.nc
#     Extracted 13 time steps for LE 2013
#   Reading HOLAPS-LE-Europe-2014_monthly.nc
#     Extracted 13 time steps for LE 2014
#   Reading HOLAPS-LE-Europe-2015_monthly.nc
#     Extracted 13 time steps for LE 2015
#   Reading HOLAPS-LE-Europe-2016_monthly.nc
#     Extracted 13 time steps for LE 2016
#   Reading HOLAPS-LE-Europe-2017_monthly.nc
#     Extracted 13 time steps for LE 2017
#   Reading HOLAPS-LE-Europe-2018_monthly.nc
#     Extracted 13 time steps for LE 2018
#   Reading HOLAPS-LE-Europe-2019_monthly.nc
#     Extracted 13 time steps for LE 2019
#   Reading HOLAPS-LE-Europe-2020_monthly.nc
#     Extracted 13 time steps for LE 2020
#   Reading HOLAPS-rain-Europe-2001_monthly.nc
#     Extracted 13 time steps for rain 2001
#   Reading HOLAPS-rain-Europe-2002_monthly.nc
#     Extracted 13 time steps for rain 2002
#   Reading HOLAPS-rain-Europe-2003_monthly.nc
#     Extracted 13 time steps for rain 2003
#   Reading HOLAPS-rain-Europe-2004_monthly.nc
#     Extracted 13 time steps for rain 2004
#   Reading HOLAPS-rain-Europe-2005_monthly.nc
#     Extracted 13 time steps for rain 2005
#   Reading HOLAPS-rain-Europe-2006_monthly.nc
#     Extracted 13 time steps for rain 2006
#   Reading HOLAPS-rain-Europe-2007_monthly.nc
#     Extracted 13 time steps for rain 2007
#   Reading HOLAPS-rain-Europe-2008_monthly.nc
#     Extracted 13 time steps for rain 2008
#   Reading HOLAPS-rain-Europe-2009_monthly.nc
#     Extracted 13 time steps for rain 2009
#   Reading HOLAPS-rain-Europe-2010_monthly.nc
#     Extracted 13 time steps for rain 2010
#   Reading HOLAPS-rain-Europe-2011_monthly.nc
#     Extracted 13 time steps for rain 2011
#   Reading HOLAPS-rain-Europe-2012_monthly.nc
#     Extracted 13 time steps for rain 2012
#   Reading HOLAPS-rain-Europe-2013_monthly.nc
#     Extracted 13 time steps for rain 2013
#   Reading HOLAPS-rain-Europe-2014_monthly.nc
#     Extracted 13 time steps for rain 2014
#   Reading HOLAPS-rain-Europe-2015_monthly.nc
#     Extracted 13 time steps for rain 2015
#   Reading HOLAPS-rain-Europe-2016_monthly.nc
#     Extracted 13 time steps for rain 2016
#   Reading HOLAPS-rain-Europe-2017_monthly.nc
#     Extracted 13 time steps for rain 2017
#   Reading HOLAPS-rain-Europe-2018_monthly.nc
#     Extracted 13 time steps for rain 2018
#   Reading HOLAPS-rain-Europe-2019_monthly.nc
#     Extracted 13 time steps for rain 2019
#   Reading HOLAPS-rain-Europe-2020_monthly.nc
#     Extracted 13 time steps for rain 2020
#   Reading HOLAPS-Rn-Europe-2001_monthly.nc
#     Extracted 13 time steps for Rn 2001
#   Reading HOLAPS-Rn-Europe-2002_monthly.nc
#     Extracted 13 time steps for Rn 2002
#   Reading HOLAPS-Rn-Europe-2003_monthly.nc
#     Extracted 13 time steps for Rn 2003
#   Reading HOLAPS-Rn-Europe-2004_monthly.nc
#     Extracted 13 time steps for Rn 2004
#   Reading HOLAPS-Rn-Europe-2005_monthly.nc
#     Extracted 13 time steps for Rn 2005
#   Reading HOLAPS-Rn-Europe-2006_monthly.nc
#     Extracted 13 time steps for Rn 2006
#   Reading HOLAPS-Rn-Europe-2007_monthly.nc
#     Extracted 13 time steps for Rn 2007
#   Reading HOLAPS-Rn-Europe-2008_monthly.nc
#     Extracted 13 time steps for Rn 2008
#   Reading HOLAPS-Rn-Europe-2009_monthly.nc
#     Extracted 13 time steps for Rn 2009
#   Reading HOLAPS-Rn-Europe-2010_monthly.nc
#     Extracted 13 time steps for Rn 2010
#   Reading HOLAPS-Rn-Europe-2011_monthly.nc
#     Extracted 13 time steps for Rn 2011
#   Reading HOLAPS-Rn-Europe-2012_monthly.nc
#     Extracted 13 time steps for Rn 2012
#   Reading HOLAPS-Rn-Europe-2013_monthly.nc
#     Extracted 13 time steps for Rn 2013
#   Reading HOLAPS-Rn-Europe-2014_monthly.nc
#     Extracted 13 time steps for Rn 2014
#   Reading HOLAPS-Rn-Europe-2015_monthly.nc
#     Extracted 13 time steps for Rn 2015
#   Reading HOLAPS-Rn-Europe-2016_monthly.nc
#     Extracted 13 time steps for Rn 2016
#   Reading HOLAPS-Rn-Europe-2017_monthly.nc
#     Extracted 13 time steps for Rn 2017
#   Reading HOLAPS-Rn-Europe-2018_monthly.nc
#     Extracted 13 time steps for Rn 2018
#   Reading HOLAPS-Rn-Europe-2019_monthly.nc
#     Extracted 13 time steps for Rn 2019
#   Reading HOLAPS-Rn-Europe-2020_monthly.nc
#     Extracted 13 time steps for Rn 2020
#   Reading HOLAPS-sm1-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm1 2001
#   Reading HOLAPS-sm1-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm1 2002
#   Reading HOLAPS-sm1-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm1 2003
#   Reading HOLAPS-sm1-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm1 2004
#   Reading HOLAPS-sm1-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm1 2005
#   Reading HOLAPS-sm1-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm1 2006
#   Reading HOLAPS-sm1-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm1 2007
#   Reading HOLAPS-sm1-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm1 2008
#   Reading HOLAPS-sm1-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm1 2009
#   Reading HOLAPS-sm1-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm1 2010
#   Reading HOLAPS-sm1-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm1 2011
#   Reading HOLAPS-sm1-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm1 2012
#   Reading HOLAPS-sm1-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm1 2013
#   Reading HOLAPS-sm1-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm1 2014
#   Reading HOLAPS-sm1-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm1 2015
#   Reading HOLAPS-sm1-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm1 2016
#   Reading HOLAPS-sm1-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm1 2017
#   Reading HOLAPS-sm1-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm1 2018
#   Reading HOLAPS-sm1-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm1 2019
#   Reading HOLAPS-sm1-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm1 2020
#   Reading HOLAPS-sm2-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm2 2001
#   Reading HOLAPS-sm2-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm2 2002
#   Reading HOLAPS-sm2-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm2 2003
#   Reading HOLAPS-sm2-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm2 2004
#   Reading HOLAPS-sm2-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm2 2005
#   Reading HOLAPS-sm2-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm2 2006
#   Reading HOLAPS-sm2-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm2 2007
#   Reading HOLAPS-sm2-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm2 2008
#   Reading HOLAPS-sm2-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm2 2009
#   Reading HOLAPS-sm2-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm2 2010
#   Reading HOLAPS-sm2-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm2 2011
#   Reading HOLAPS-sm2-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm2 2012
#   Reading HOLAPS-sm2-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm2 2013
#   Reading HOLAPS-sm2-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm2 2014
#   Reading HOLAPS-sm2-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm2 2015
#   Reading HOLAPS-sm2-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm2 2016
#   Reading HOLAPS-sm2-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm2 2017
#   Reading HOLAPS-sm2-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm2 2018
#   Reading HOLAPS-sm2-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm2 2019
#   Reading HOLAPS-sm2-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm2 2020
#   Reading HOLAPS-sm3-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm3 2001
#   Reading HOLAPS-sm3-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm3 2002
#   Reading HOLAPS-sm3-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm3 2003
#   Reading HOLAPS-sm3-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm3 2004
#   Reading HOLAPS-sm3-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm3 2005
#   Reading HOLAPS-sm3-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm3 2006
#   Reading HOLAPS-sm3-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm3 2007
#   Reading HOLAPS-sm3-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm3 2008
#   Reading HOLAPS-sm3-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm3 2009
#   Reading HOLAPS-sm3-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm3 2010
#   Reading HOLAPS-sm3-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm3 2011
#   Reading HOLAPS-sm3-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm3 2012
#   Reading HOLAPS-sm3-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm3 2013
#   Reading HOLAPS-sm3-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm3 2014
#   Reading HOLAPS-sm3-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm3 2015
#   Reading HOLAPS-sm3-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm3 2016
#   Reading HOLAPS-sm3-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm3 2017
#   Reading HOLAPS-sm3-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm3 2018
#   Reading HOLAPS-sm3-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm3 2019
#   Reading HOLAPS-sm3-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm3 2020
#   Reading HOLAPS-sm4-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm4 2001
#   Reading HOLAPS-sm4-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm4 2002
#   Reading HOLAPS-sm4-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm4 2003
#   Reading HOLAPS-sm4-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm4 2004
#   Reading HOLAPS-sm4-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm4 2005
#   Reading HOLAPS-sm4-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm4 2006
#   Reading HOLAPS-sm4-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm4 2007
#   Reading HOLAPS-sm4-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm4 2008
#   Reading HOLAPS-sm4-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm4 2009
#   Reading HOLAPS-sm4-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm4 2010
#   Reading HOLAPS-sm4-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm4 2011
#   Reading HOLAPS-sm4-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm4 2012
#   Reading HOLAPS-sm4-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm4 2013
#   Reading HOLAPS-sm4-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm4 2014
#   Reading HOLAPS-sm4-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm4 2015
#   Reading HOLAPS-sm4-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm4 2016
#   Reading HOLAPS-sm4-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm4 2017
#   Reading HOLAPS-sm4-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm4 2018
#   Reading HOLAPS-sm4-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm4 2019
#   Reading HOLAPS-sm4-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm4 2020
#   Reading HOLAPS-sm5-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm5 2001
#   Reading HOLAPS-sm5-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm5 2002
#   Reading HOLAPS-sm5-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm5 2003
#   Reading HOLAPS-sm5-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm5 2004
#   Reading HOLAPS-sm5-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm5 2005
#   Reading HOLAPS-sm5-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm5 2006
#   Reading HOLAPS-sm5-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm5 2007
#   Reading HOLAPS-sm5-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm5 2008
#   Reading HOLAPS-sm5-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm5 2009
#   Reading HOLAPS-sm5-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm5 2010
#   Reading HOLAPS-sm5-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm5 2011
#   Reading HOLAPS-sm5-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm5 2012
#   Reading HOLAPS-sm5-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm5 2013
#   Reading HOLAPS-sm5-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm5 2014
#   Reading HOLAPS-sm5-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm5 2015
#   Reading HOLAPS-sm5-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm5 2016
#   Reading HOLAPS-sm5-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm5 2017
#   Reading HOLAPS-sm5-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm5 2018
#   Reading HOLAPS-sm5-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm5 2019
#   Reading HOLAPS-sm5-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm5 2020
#   Reading HOLAPS-Ta-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ta 2001
#   Reading HOLAPS-Ta-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ta 2002
#   Reading HOLAPS-Ta-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ta 2003
#   Reading HOLAPS-Ta-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ta 2004
#   Reading HOLAPS-Ta-Europe-2005_monthly.nc
#     Extracted 13 time steps for Ta 2005
#   Reading HOLAPS-Ta-Europe-2006_monthly.nc
#     Extracted 13 time steps for Ta 2006
#   Reading HOLAPS-Ta-Europe-2007_monthly.nc
#     Extracted 13 time steps for Ta 2007
#   Reading HOLAPS-Ta-Europe-2008_monthly.nc
#     Extracted 13 time steps for Ta 2008
#   Reading HOLAPS-Ta-Europe-2009_monthly.nc
#     Extracted 13 time steps for Ta 2009
#   Reading HOLAPS-Ta-Europe-2010_monthly.nc
#     Extracted 13 time steps for Ta 2010
#   Reading HOLAPS-Ta-Europe-2011_monthly.nc
#     Extracted 13 time steps for Ta 2011
#   Reading HOLAPS-Ta-Europe-2012_monthly.nc
#     Extracted 13 time steps for Ta 2012
#   Reading HOLAPS-Ta-Europe-2013_monthly.nc
#     Extracted 13 time steps for Ta 2013
#   Reading HOLAPS-Ta-Europe-2014_monthly.nc
#     Extracted 13 time steps for Ta 2014
#   Reading HOLAPS-Ta-Europe-2015_monthly.nc
#     Extracted 13 time steps for Ta 2015
#   Reading HOLAPS-Ta-Europe-2016_monthly.nc
#     Extracted 13 time steps for Ta 2016
#   Reading HOLAPS-Ta-Europe-2017_monthly.nc
#     Extracted 13 time steps for Ta 2017
#   Reading HOLAPS-Ta-Europe-2018_monthly.nc
#     Extracted 13 time steps for Ta 2018
#   Reading HOLAPS-Ta-Europe-2019_monthly.nc
#     Extracted 13 time steps for Ta 2019
#   Reading HOLAPS-Ta-Europe-2020_monthly.nc
#     Extracted 13 time steps for Ta 2020
#   Reading HOLAPS-Td-Europe-2001_monthly.nc
#     Extracted 13 time steps for Td 2001
#   Reading HOLAPS-Td-Europe-2002_monthly.nc
#     Extracted 13 time steps for Td 2002
#   Reading HOLAPS-Td-Europe-2003_monthly.nc
#     Extracted 13 time steps for Td 2003
#   Reading HOLAPS-Td-Europe-2004_monthly.nc
#     Extracted 13 time steps for Td 2004
#   Reading HOLAPS-Td-Europe-2005_monthly.nc
#     Extracted 13 time steps for Td 2005
#   Reading HOLAPS-Td-Europe-2006_monthly.nc
#     Extracted 13 time steps for Td 2006
#   Reading HOLAPS-Td-Europe-2007_monthly.nc
#     Extracted 13 time steps for Td 2007
#   Reading HOLAPS-Td-Europe-2008_monthly.nc
#     Extracted 13 time steps for Td 2008
#   Reading HOLAPS-Td-Europe-2009_monthly.nc
#     Extracted 13 time steps for Td 2009
#   Reading HOLAPS-Td-Europe-2010_monthly.nc
#     Extracted 13 time steps for Td 2010
#   Reading HOLAPS-Td-Europe-2011_monthly.nc
#     Extracted 13 time steps for Td 2011
#   Reading HOLAPS-Td-Europe-2012_monthly.nc
#     Extracted 13 time steps for Td 2012
#   Reading HOLAPS-Td-Europe-2013_monthly.nc
#     Extracted 13 time steps for Td 2013
#   Reading HOLAPS-Td-Europe-2014_monthly.nc
#     Extracted 13 time steps for Td 2014
#   Reading HOLAPS-Td-Europe-2015_monthly.nc
#     Extracted 13 time steps for Td 2015
#   Reading HOLAPS-Td-Europe-2016_monthly.nc
#     Extracted 13 time steps for Td 2016
#   Reading HOLAPS-Td-Europe-2017_monthly.nc
#     Extracted 13 time steps for Td 2017
#   Reading HOLAPS-Td-Europe-2018_monthly.nc
#     Extracted 13 time steps for Td 2018
#   Reading HOLAPS-Td-Europe-2019_monthly.nc
#     Extracted 13 time steps for Td 2019
#   Reading HOLAPS-Td-Europe-2020_monthly.nc
#     Extracted 13 time steps for Td 2020
#   Reading HOLAPS-Ts-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ts 2001
#   Reading HOLAPS-Ts-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ts 2002
#   Reading HOLAPS-Ts-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ts 2003
#   Reading HOLAPS-Ts-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ts 2004
#   Reading HOLAPS-Ts-Europe-2005_monthly.nc
#     Extracted 13 time steps for Ts 2005
#   Reading HOLAPS-Ts-Europe-2006_monthly.nc
#     Extracted 13 time steps for Ts 2006
#   Reading HOLAPS-Ts-Europe-2007_monthly.nc
#     Extracted 13 time steps for Ts 2007
#   Reading HOLAPS-Ts-Europe-2008_monthly.nc
#     Extracted 13 time steps for Ts 2008
#   Reading HOLAPS-Ts-Europe-2009_monthly.nc
#     Extracted 13 time steps for Ts 2009
#   Reading HOLAPS-Ts-Europe-2010_monthly.nc
#     Extracted 13 time steps for Ts 2010
#   Reading HOLAPS-Ts-Europe-2011_monthly.nc
#     Extracted 13 time steps for Ts 2011
#   Reading HOLAPS-Ts-Europe-2012_monthly.nc
#     Extracted 13 time steps for Ts 2012
#   Reading HOLAPS-Ts-Europe-2013_monthly.nc
#     Extracted 13 time steps for Ts 2013
#   Reading HOLAPS-Ts-Europe-2014_monthly.nc
#     Extracted 13 time steps for Ts 2014
#   Reading HOLAPS-Ts-Europe-2015_monthly.nc
#     Extracted 13 time steps for Ts 2015
#   Reading HOLAPS-Ts-Europe-2016_monthly.nc
#     Extracted 13 time steps for Ts 2016
#   Reading HOLAPS-Ts-Europe-2017_monthly.nc
#     Extracted 13 time steps for Ts 2017
#   Reading HOLAPS-Ts-Europe-2018_monthly.nc
#     Extracted 13 time steps for Ts 2018
#   Reading HOLAPS-Ts-Europe-2019_monthly.nc
#     Extracted 13 time steps for Ts 2019
#   Reading HOLAPS-Ts-Europe-2020_monthly.nc
#     Extracted 13 time steps for Ts 2020
# ✓ Saved: station_data1\BE-Bra_all_variables.csv with 240 records
#   Years: 20 (2001-2020)
#   Variables: ['GHF', 'H', 'LE', 'Rn', 'Ta', 'Td', 'Ts', 'rain', 'sm1', 'sm2', 'sm3', 'sm4', 'sm5']
#
# Processing station: BE-Lon
#   Found 260 NetCDF files
#   Reading HOLAPS-GHF-Europe-2001_monthly.nc
#     Extracted 13 time steps for GHF 2001
#   Reading HOLAPS-GHF-Europe-2002_monthly.nc
#     Extracted 13 time steps for GHF 2002
#   Reading HOLAPS-GHF-Europe-2003_monthly.nc
#     Extracted 13 time steps for GHF 2003
#   Reading HOLAPS-GHF-Europe-2004_monthly.nc
#     Extracted 13 time steps for GHF 2004
#   Reading HOLAPS-GHF-Europe-2005_monthly.nc
#     Extracted 13 time steps for GHF 2005
#   Reading HOLAPS-GHF-Europe-2006_monthly.nc
#     Extracted 13 time steps for GHF 2006
#   Reading HOLAPS-GHF-Europe-2007_monthly.nc
#     Extracted 13 time steps for GHF 2007
#   Reading HOLAPS-GHF-Europe-2008_monthly.nc
#     Extracted 13 time steps for GHF 2008
#   Reading HOLAPS-GHF-Europe-2009_monthly.nc
#     Extracted 13 time steps for GHF 2009
#   Reading HOLAPS-GHF-Europe-2010_monthly.nc
#     Extracted 13 time steps for GHF 2010
#   Reading HOLAPS-GHF-Europe-2011_monthly.nc
#     Extracted 13 time steps for GHF 2011
#   Reading HOLAPS-GHF-Europe-2012_monthly.nc
#     Extracted 13 time steps for GHF 2012
#   Reading HOLAPS-GHF-Europe-2013_monthly.nc
#     Extracted 13 time steps for GHF 2013
#   Reading HOLAPS-GHF-Europe-2014_monthly.nc
#     Extracted 13 time steps for GHF 2014
#   Reading HOLAPS-GHF-Europe-2015_monthly.nc
#     Extracted 13 time steps for GHF 2015
#   Reading HOLAPS-GHF-Europe-2016_monthly.nc
#     Extracted 13 time steps for GHF 2016
#   Reading HOLAPS-GHF-Europe-2017_monthly.nc
#     Extracted 13 time steps for GHF 2017
#   Reading HOLAPS-GHF-Europe-2018_monthly.nc
#     Extracted 13 time steps for GHF 2018
#   Reading HOLAPS-GHF-Europe-2019_monthly.nc
#     Extracted 13 time steps for GHF 2019
#   Reading HOLAPS-GHF-Europe-2020_monthly.nc
#     Extracted 13 time steps for GHF 2020
#   Reading HOLAPS-H-Europe-2001_monthly.nc
#     Extracted 13 time steps for H 2001
#   Reading HOLAPS-H-Europe-2002_monthly.nc
#     Extracted 13 time steps for H 2002
#   Reading HOLAPS-H-Europe-2003_monthly.nc
#     Extracted 13 time steps for H 2003
#   Reading HOLAPS-H-Europe-2004_monthly.nc
#     Extracted 13 time steps for H 2004
#   Reading HOLAPS-H-Europe-2005_monthly.nc
#     Extracted 13 time steps for H 2005
#   Reading HOLAPS-H-Europe-2006_monthly.nc
#     Extracted 13 time steps for H 2006
#   Reading HOLAPS-H-Europe-2007_monthly.nc
#     Extracted 13 time steps for H 2007
#   Reading HOLAPS-H-Europe-2008_monthly.nc
#     Extracted 13 time steps for H 2008
#   Reading HOLAPS-H-Europe-2009_monthly.nc
#     Extracted 13 time steps for H 2009
#   Reading HOLAPS-H-Europe-2010_monthly.nc
#     Extracted 13 time steps for H 2010
#   Reading HOLAPS-H-Europe-2011_monthly.nc
#     Extracted 13 time steps for H 2011
#   Reading HOLAPS-H-Europe-2012_monthly.nc
#     Extracted 13 time steps for H 2012
#   Reading HOLAPS-H-Europe-2013_monthly.nc
#     Extracted 13 time steps for H 2013
#   Reading HOLAPS-H-Europe-2014_monthly.nc
#     Extracted 13 time steps for H 2014
#   Reading HOLAPS-H-Europe-2015_monthly.nc
#     Extracted 13 time steps for H 2015
#   Reading HOLAPS-H-Europe-2016_monthly.nc
#     Extracted 13 time steps for H 2016
#   Reading HOLAPS-H-Europe-2017_monthly.nc
#     Extracted 13 time steps for H 2017
#   Reading HOLAPS-H-Europe-2018_monthly.nc
#     Extracted 13 time steps for H 2018
#   Reading HOLAPS-H-Europe-2019_monthly.nc
#     Extracted 13 time steps for H 2019
#   Reading HOLAPS-H-Europe-2020_monthly.nc
#     Extracted 13 time steps for H 2020
#   Reading HOLAPS-LE-Europe-2001_monthly.nc
#     Extracted 13 time steps for LE 2001
#   Reading HOLAPS-LE-Europe-2002_monthly.nc
#     Extracted 13 time steps for LE 2002
#   Reading HOLAPS-LE-Europe-2003_monthly.nc
#     Extracted 13 time steps for LE 2003
#   Reading HOLAPS-LE-Europe-2004_monthly.nc
#     Extracted 13 time steps for LE 2004
#   Reading HOLAPS-LE-Europe-2005_monthly.nc
#     Extracted 13 time steps for LE 2005
# ...
#     Extracted 13 time steps for sm3 2003
#   Reading HOLAPS-sm3-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm3 2004
#   Reading HOLAPS-sm3-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm3 2005
#   Reading HOLAPS-sm3-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm3 2006
#   Reading HOLAPS-sm3-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm3 2007
#   Reading HOLAPS-sm3-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm3 2008
#   Reading HOLAPS-sm3-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm3 2009
#   Reading HOLAPS-sm3-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm3 2010
#   Reading HOLAPS-sm3-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm3 2011
#   Reading HOLAPS-sm3-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm3 2012
#   Reading HOLAPS-sm3-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm3 2013
#   Reading HOLAPS-sm3-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm3 2014
#   Reading HOLAPS-sm3-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm3 2015
#   Reading HOLAPS-sm3-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm3 2016
#   Reading HOLAPS-sm3-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm3 2017
#   Reading HOLAPS-sm3-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm3 2018
#   Reading HOLAPS-sm3-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm3 2019
#   Reading HOLAPS-sm3-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm3 2020
#   Reading HOLAPS-sm4-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm4 2001
#   Reading HOLAPS-sm4-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm4 2002
#   Reading HOLAPS-sm4-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm4 2003
#   Reading HOLAPS-sm4-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm4 2004
#   Reading HOLAPS-sm4-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm4 2005
#   Reading HOLAPS-sm4-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm4 2006
#   Reading HOLAPS-sm4-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm4 2007
#   Reading HOLAPS-sm4-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm4 2008
#   Reading HOLAPS-sm4-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm4 2009
#   Reading HOLAPS-sm4-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm4 2010
#   Reading HOLAPS-sm4-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm4 2011
#   Reading HOLAPS-sm4-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm4 2012
#   Reading HOLAPS-sm4-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm4 2013
#   Reading HOLAPS-sm4-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm4 2014
#   Reading HOLAPS-sm4-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm4 2015
#   Reading HOLAPS-sm4-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm4 2016
#   Reading HOLAPS-sm4-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm4 2017
#   Reading HOLAPS-sm4-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm4 2018
#   Reading HOLAPS-sm4-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm4 2019
#   Reading HOLAPS-sm4-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm4 2020
#   Reading HOLAPS-sm5-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm5 2001
#   Reading HOLAPS-sm5-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm5 2002
#   Reading HOLAPS-sm5-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm5 2003
#   Reading HOLAPS-sm5-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm5 2004
#   Reading HOLAPS-sm5-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm5 2005
#   Reading HOLAPS-sm5-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm5 2006
#   Reading HOLAPS-sm5-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm5 2007
#   Reading HOLAPS-sm5-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm5 2008
#   Reading HOLAPS-sm5-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm5 2009
#   Reading HOLAPS-sm5-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm5 2010
#   Reading HOLAPS-sm5-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm5 2011
#   Reading HOLAPS-sm5-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm5 2012
#   Reading HOLAPS-sm5-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm5 2013
#   Reading HOLAPS-sm5-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm5 2014
#   Reading HOLAPS-sm5-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm5 2015
#   Reading HOLAPS-sm5-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm5 2016
#   Reading HOLAPS-sm5-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm5 2017
#   Reading HOLAPS-sm5-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm5 2018
#   Reading HOLAPS-sm5-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm5 2019
#   Reading HOLAPS-sm5-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm5 2020
#   Reading HOLAPS-Ta-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ta 2001
#   Reading HOLAPS-Ta-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ta 2002
#   Reading HOLAPS-Ta-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ta 2003
#   Reading HOLAPS-Ta-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ta 2004
#   Reading HOLAPS-Ta-Europe-2005_monthly.nc
#     Extracted 13 time steps for Ta 2005
#   Reading HOLAPS-Ta-Europe-2006_monthly.nc
#     Extracted 13 time steps for Ta 2006
#   Reading HOLAPS-Ta-Europe-2007_monthly.nc
#     Extracted 13 time steps for Ta 2007
#   Reading HOLAPS-Ta-Europe-2008_monthly.nc
#     Extracted 13 time steps for Ta 2008
#   Reading HOLAPS-Ta-Europe-2009_monthly.nc
#     Extracted 13 time steps for Ta 2009
#   Reading HOLAPS-Ta-Europe-2010_monthly.nc
#     Extracted 13 time steps for Ta 2010
#   Reading HOLAPS-Ta-Europe-2011_monthly.nc
#     Extracted 13 time steps for Ta 2011
#   Reading HOLAPS-Ta-Europe-2012_monthly.nc
#     Extracted 13 time steps for Ta 2012
#   Reading HOLAPS-Ta-Europe-2013_monthly.nc
#     Extracted 13 time steps for Ta 2013
#   Reading HOLAPS-Ta-Europe-2014_monthly.nc
#     Extracted 13 time steps for Ta 2014
#   Reading HOLAPS-Ta-Europe-2015_monthly.nc
#     Extracted 13 time steps for Ta 2015
#   Reading HOLAPS-Ta-Europe-2016_monthly.nc
#     Extracted 13 time steps for Ta 2016
#   Reading HOLAPS-Ta-Europe-2017_monthly.nc
#     Extracted 13 time steps for Ta 2017
#   Reading HOLAPS-Ta-Europe-2018_monthly.nc
#     Extracted 13 time steps for Ta 2018
#   Reading HOLAPS-Ta-Europe-2019_monthly.nc
#     Extracted 13 time steps for Ta 2019
#   Reading HOLAPS-Ta-Europe-2020_monthly.nc
#     Extracted 13 time steps for Ta 2020
#   Reading HOLAPS-Td-Europe-2001_monthly.nc
#     Extracted 13 time steps for Td 2001
#   Reading HOLAPS-Td-Europe-2002_monthly.nc
#     Extracted 13 time steps for Td 2002
#   Reading HOLAPS-Td-Europe-2003_monthly.nc
#     Extracted 13 time steps for Td 2003
#   Reading HOLAPS-Td-Europe-2004_monthly.nc
#     Extracted 13 time steps for Td 2004
#   Reading HOLAPS-Td-Europe-2005_monthly.nc
#     Extracted 13 time steps for Td 2005
#   Reading HOLAPS-Td-Europe-2006_monthly.nc
#     Extracted 13 time steps for Td 2006
#   Reading HOLAPS-Td-Europe-2007_monthly.nc
#     Extracted 13 time steps for Td 2007
#   Reading HOLAPS-Td-Europe-2008_monthly.nc
#     Extracted 13 time steps for Td 2008
#   Reading HOLAPS-Td-Europe-2009_monthly.nc
#     Extracted 13 time steps for Td 2009
#   Reading HOLAPS-Td-Europe-2010_monthly.nc
#     Extracted 13 time steps for Td 2010
#   Reading HOLAPS-Td-Europe-2011_monthly.nc
#     Extracted 13 time steps for Td 2011
#   Reading HOLAPS-Td-Europe-2012_monthly.nc
#     Extracted 13 time steps for Td 2012
#   Reading HOLAPS-Td-Europe-2013_monthly.nc
#     Extracted 13 time steps for Td 2013
#   Reading HOLAPS-Td-Europe-2014_monthly.nc
#     Extracted 13 time steps for Td 2014
#   Reading HOLAPS-Td-Europe-2015_monthly.nc
#     Extracted 13 time steps for Td 2015
#   Reading HOLAPS-Td-Europe-2016_monthly.nc
#     Extracted 13 time steps for Td 2016
#   Reading HOLAPS-Td-Europe-2017_monthly.nc
#     Extracted 13 time steps for Td 2017
#   Reading HOLAPS-Td-Europe-2018_monthly.nc
#     Extracted 13 time steps for Td 2018
#   Reading HOLAPS-Td-Europe-2019_monthly.nc
#     Extracted 13 time steps for Td 2019
#   Reading HOLAPS-Td-Europe-2020_monthly.nc
#     Extracted 13 time steps for Td 2020
#   Reading HOLAPS-Ts-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ts 2001
#   Reading HOLAPS-Ts-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ts 2002
#   Reading HOLAPS-Ts-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ts 2003
#   Reading HOLAPS-Ts-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ts 2004
#   Reading HOLAPS-Ts-Europe-2005_monthly.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 131
#     128         print()
#     130 # Run the final version
# --> 131 create_station_csvs_final()
#
# Cell In[1], line 45, in create_station_csvs_final()
#      42 var = var_match.group(1)
#      44 print(f"  Reading {filename}")
# ---> 45 ds = xr.open_dataset(file_path)
#      47 # Use nearest neighbor selection
#      48 closest_data = ds.sel(
#      49     latitude=station_lat,
#      50     longitude=station_lon,
#      51     method='nearest'
#      52 )
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\backends\api.py:602, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     595 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
#     596 backend_ds = backend.open_dataset(
#     597     filename_or_obj,
#     598     drop_variables=drop_variables,
#     599     **decoders,
#     600     **kwargs,
#     601 )
# --> 602 ds = _dataset_from_backend_dataset(
#     603     backend_ds,
#     604     filename_or_obj,
#     605     engine,
#     606     chunks,
#     607     cache,
#     608     overwrite_encoded_chunks,
#     609     inline_array,
#     610     chunked_array_type,
#     611     from_array_kwargs,
#     612     drop_variables=drop_variables,
#     613     create_default_indexes=create_default_indexes,
#     614     **decoders,
#     615     **kwargs,
#     616 )
#     617 return ds
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\backends\api.py:292, in _dataset_from_backend_dataset(backend_ds, filename_or_obj, engine, chunks, cache, overwrite_encoded_chunks, inline_array, chunked_array_type, from_array_kwargs, create_default_indexes, **extra_tokens)
#     289 _protect_dataset_variables_inplace(backend_ds, cache)
#     291 if create_default_indexes:
# --> 292     ds = _maybe_create_default_indexes(backend_ds)
#     293 else:
#     294     ds = backend_ds
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\backends\api.py:268, in _maybe_create_default_indexes(ds)
#     262 def _maybe_create_default_indexes(ds):
#     263     to_index = {
#     264         name: coord.variable
#     265         for name, coord in ds.coords.items()
#     266         if coord.dims == (name,) and name not in ds.xindexes
#     267     }
# --> 268     return ds.assign_coords(Coordinates(to_index))
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\core\coordinates.py:315, in Coordinates.__init__(self, coords, indexes)
#     313 var = as_variable(data, name=name, auto_convert=False)
#     314 if var.dims == (name,) and indexes is None:
# --> 315     index, index_vars = create_default_index_implicit(var, list(coords))
#     316     default_indexes.update(dict.fromkeys(index_vars, index))
#     317     variables.update(index_vars)
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\core\indexes.py:1638, in create_default_index_implicit(dim_variable, all_variables)
#    1636 else:
#    1637     dim_var = {name: dim_variable}
# -> 1638     index = PandasIndex.from_variables(dim_var, options={})
#    1639     index_vars = index.create_variables(dim_var)
#    1641 return index, index_vars
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\core\indexes.py:720, in PandasIndex.from_variables(cls, variables, options)
#     712 dim = var.dims[0]
#     714 # TODO: (benbovy - explicit indexes): add __index__ to ExplicitlyIndexesNDArrayMixin?
#     715 # this could be eventually used by Variable.to_index() and would remove the need to perform
#     716 # the checks below.
#     717
#     718 # preserve wrapped pd.Index (if any)
#     719 # accessing `.data` can load data from disk, so we only access if needed
# --> 720 data = var._data if isinstance(var._data, PandasIndexingAdapter) else var.data  # type: ignore[redundant-expr]
#     721 # multi-index level variable: get level index
#     722 if isinstance(var._data, PandasMultiIndexingAdapter):
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\core\variable.py:456, in Variable.data(self)
#     454     duck_array = self._data.array
#     455 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 456     duck_array = self._data.get_duck_array()
#     457 elif is_duck_array(self._data):
#     458     duck_array = self._data
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\core\indexing.py:943, in MemoryCachedArray.get_duck_array(self)
#     942 def get_duck_array(self):
# --> 943     duck_array = self.array.get_duck_array()
#     944     # ensure the array object is cached in-memory
#     945     self.array = as_indexable(duck_array)
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\core\indexing.py:897, in CopyOnWriteArray.get_duck_array(self)
#     896 def get_duck_array(self):
# --> 897     return self.array.get_duck_array()
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\core\indexing.py:737, in LazilyIndexedArray.get_duck_array(self)
#     734 from xarray.backends.common import BackendArray
#     736 if isinstance(self.array, BackendArray):
# --> 737     array = self.array[self.key]
#     738 else:
#     739     array = apply_indexer(self.array, self.key)
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\backends\netCDF4_.py:116, in NetCDF4ArrayWrapper.__getitem__(self, key)
#     115 def __getitem__(self, key):
# --> 116     return indexing.explicit_indexing_adapter(
#     117         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     118     )
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\core\indexing.py:1129, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1107 """Support explicit indexing by delegating to a raw indexing method.
#    1108
#    1109 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)   1126 Indexing result, in the form of a duck numpy-array.
#    1127 """
#    1128 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1129 result = raw_indexing_method(raw_key.tuple)
#    1130 if numpy_indices.tuple:
#    1131     # index the loaded duck array
#    1132     indexable = as_indexable(result)
#
# File c:\Users\chinthap\AppData\Local\miniconda3\envs\new\Lib\site-packages\xarray\backends\netCDF4_.py:129, in NetCDF4ArrayWrapper._getitem(self, key)
#     127     with self.datastore.lock:
#     128         original_array = self.get_array(needs_lock=False)
# --> 129         array = getitem(original_array, key)
#     130 except IndexError as err:
#     131     # Catch IndexError in netCDF4 and return a more informative
#     132     # error message.  This is most often called when an unsorted
#     133     # indexer is used before the data is loaded from disk.
#     134     msg = (
#     135         "The indexing operation you are attempting to perform "
#     136         "is not valid on netCDF4.Variable object. Try loading "
#     137         "your data into memory first by calling .load()."
#     138     )
#
# KeyboardInterrupt:

# %%
import xarray as xr
import pandas as pd
import glob
import os
import numpy as np
import re

def create_station_csvs_final():
    """Final working version with model grid coordinates"""
    
    netcdf_folder = r"C:\Deepak\HOLAPS\monthly"
    stations_csv = "plot_sites_coordinates2.csv"
    output_folder = "station_data2"
    
    os.makedirs(output_folder, exist_ok=True)
    stations_df = pd.read_csv(stations_csv)
    
    for _, station in stations_df.iterrows():
        station_id = station['SITE_ID']
        station_lat = station['LATITUDE']
        station_lon = station['LONGITUDE']
        
        print(f"Processing station: {station_id}")
        all_station_data = []
        
        # Get all NetCDF files
        all_nc_files = glob.glob(os.path.join(netcdf_folder, "*.nc"))
        print(f"  Found {len(all_nc_files)} NetCDF files")
        
        for file_path in all_nc_files:
            try:
                filename = os.path.basename(file_path)
                
                # Extract year and variable
                year_match = re.search(r'(\d{4})', filename)
                var_match = re.search(r'HOLAPS-([A-Za-z0-9]+)-Europe', filename)
                
                if not year_match or not var_match:
                    continue
                
                year = int(year_match.group(1))
                var = var_match.group(1)
                
                print(f"  Reading {filename}")
                ds = xr.open_dataset(file_path)
                
                # Use nearest neighbor selection
                closest_data = ds.sel(
                    latitude=station_lat,
                    longitude=station_lon,
                    method='nearest'
                )
                
                # Get the ACTUAL model grid coordinates that were selected
                model_lat = float(closest_data.latitude.values)
                model_lon = float(closest_data.longitude.values)
                
                # Calculate distance from station to model grid point
                distance = np.sqrt((model_lat - station_lat)**2 + (model_lon - station_lon)**2)
                
                # Get data variable (exclude bounds variables)
                data_vars = [v for v in ds.data_vars.keys() if 'bnds' not in v]
                if not data_vars:
                    ds.close()
                    continue
                
                data_var = data_vars[0]
                
                # Extract data - handle different data shapes
                data_values = closest_data[data_var]
                
                # Convert to numpy array and ensure it's 1D
                if data_values.ndim == 0:  # Scalar
                    data_values = np.array([data_values.values])
                else:  # Array
                    data_values = data_values.values
                
                # Flatten if needed to get 1D time series
                if data_values.ndim > 1:
                    data_values = data_values.flatten()
                
                time_size = len(data_values)
                print(f"    Extracted {time_size} time steps for {var} {year}")
                print(f"    Model grid: ({model_lat:.4f}, {model_lon:.4f}), Distance: {distance:.4f}°")
                
                for time_idx, value in enumerate(data_values):
                    if not pd.isna(value):
                        # Handle the 13-month issue: skip first if 13 months
                        if time_size == 13 and time_idx == 0:
                            continue  # Skip first month
                        
                        actual_month = time_idx + 1 if time_size != 13 else time_idx
                        
                        all_station_data.append({
                            'station_id': station_id,
                            'year': year,
                            'month': actual_month,
                            'variable': var,
                            'value': float(value),
                            'station_latitude': station_lat,    # Original station coordinates
                            'station_longitude': station_lon,   # Original station coordinates
                            'model_latitude': model_lat,        # Actual model grid point used
                            'model_longitude': model_lon,       # Actual model grid point used
                            'grid_distance_degrees': distance   # Distance between station and grid point
                        })
                
                ds.close()
                
            except Exception as e:
                print(f"Error with {file_path}: {e}")
                continue
        
        # Save station data
        if all_station_data:
            df = pd.DataFrame(all_station_data)
            
            try:
                df_wide = df.pivot_table(
                    index=['station_id', 'year', 'month', 'station_latitude', 'station_longitude', 
                           'model_latitude', 'model_longitude', 'grid_distance_degrees'],
                    columns='variable', 
                    values='value'
                ).reset_index()
                
                output_file = os.path.join(output_folder, f"{station_id}_all_variables.csv")
                df_wide.to_csv(output_file, index=False)
                print(f"✓ Saved: {output_file} with {len(df_wide)} records")
                
                # Show summary including grid info
                years = df_wide['year'].unique()
                avg_distance = df_wide['grid_distance_degrees'].mean()
                variables = [col for col in df_wide.columns if col not in [
                    'station_id', 'year', 'month', 'station_latitude', 'station_longitude',
                    'model_latitude', 'model_longitude', 'grid_distance_degrees'
                ]]
                
                print(f"  Years: {len(years)} ({min(years)}-{max(years)})")
                print(f"  Variables: {variables}")
                print(f"  Avg grid distance: {avg_distance:.4f}°")
                
            except Exception as e:
                print(f"Error creating wide format: {e}")
        else:
            print(f"✗ No data found for station {station_id}")
        
        print()

# Run the final version
create_station_csvs_final()
# Out:
# Processing station: AT-Neu
#   Found 260 NetCDF files
#   Reading HOLAPS-GHF-Europe-2001_monthly.nc
#     Extracted 13 time steps for GHF 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2002_monthly.nc
#     Extracted 13 time steps for GHF 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2003_monthly.nc
#     Extracted 13 time steps for GHF 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2004_monthly.nc
#     Extracted 13 time steps for GHF 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2005_monthly.nc
#     Extracted 13 time steps for GHF 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2006_monthly.nc
#     Extracted 13 time steps for GHF 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2007_monthly.nc
#     Extracted 13 time steps for GHF 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2008_monthly.nc
#     Extracted 13 time steps for GHF 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2009_monthly.nc
#     Extracted 13 time steps for GHF 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2010_monthly.nc
#     Extracted 13 time steps for GHF 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2011_monthly.nc
#     Extracted 13 time steps for GHF 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2012_monthly.nc
#     Extracted 13 time steps for GHF 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2013_monthly.nc
#     Extracted 13 time steps for GHF 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2014_monthly.nc
#     Extracted 13 time steps for GHF 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2015_monthly.nc
#     Extracted 13 time steps for GHF 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2016_monthly.nc
#     Extracted 13 time steps for GHF 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2017_monthly.nc
#     Extracted 13 time steps for GHF 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2018_monthly.nc
#     Extracted 13 time steps for GHF 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2019_monthly.nc
#     Extracted 13 time steps for GHF 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-GHF-Europe-2020_monthly.nc
#     Extracted 13 time steps for GHF 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2001_monthly.nc
#     Extracted 13 time steps for H 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2002_monthly.nc
#     Extracted 13 time steps for H 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2003_monthly.nc
#     Extracted 13 time steps for H 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2004_monthly.nc
#     Extracted 13 time steps for H 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2005_monthly.nc
#     Extracted 13 time steps for H 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2006_monthly.nc
#     Extracted 13 time steps for H 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2007_monthly.nc
#     Extracted 13 time steps for H 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2008_monthly.nc
#     Extracted 13 time steps for H 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2009_monthly.nc
#     Extracted 13 time steps for H 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2010_monthly.nc
#     Extracted 13 time steps for H 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2011_monthly.nc
#     Extracted 13 time steps for H 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2012_monthly.nc
#     Extracted 13 time steps for H 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2013_monthly.nc
#     Extracted 13 time steps for H 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2014_monthly.nc
#     Extracted 13 time steps for H 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2015_monthly.nc
#     Extracted 13 time steps for H 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2016_monthly.nc
#     Extracted 13 time steps for H 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2017_monthly.nc
#     Extracted 13 time steps for H 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2018_monthly.nc
#     Extracted 13 time steps for H 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2019_monthly.nc
#     Extracted 13 time steps for H 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-H-Europe-2020_monthly.nc
#     Extracted 13 time steps for H 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2001_monthly.nc
#     Extracted 13 time steps for LE 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2002_monthly.nc
#     Extracted 13 time steps for LE 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2003_monthly.nc
#     Extracted 13 time steps for LE 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2004_monthly.nc
#     Extracted 13 time steps for LE 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2005_monthly.nc
#     Extracted 13 time steps for LE 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2006_monthly.nc
#     Extracted 13 time steps for LE 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2007_monthly.nc
#     Extracted 13 time steps for LE 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2008_monthly.nc
#     Extracted 13 time steps for LE 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2009_monthly.nc
#     Extracted 13 time steps for LE 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2010_monthly.nc
#     Extracted 13 time steps for LE 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2011_monthly.nc
#     Extracted 13 time steps for LE 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2012_monthly.nc
#     Extracted 13 time steps for LE 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2013_monthly.nc
#     Extracted 13 time steps for LE 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2014_monthly.nc
#     Extracted 13 time steps for LE 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2015_monthly.nc
#     Extracted 13 time steps for LE 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2016_monthly.nc
#     Extracted 13 time steps for LE 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2017_monthly.nc
#     Extracted 13 time steps for LE 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2018_monthly.nc
#     Extracted 13 time steps for LE 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2019_monthly.nc
#     Extracted 13 time steps for LE 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-LE-Europe-2020_monthly.nc
#     Extracted 13 time steps for LE 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2001_monthly.nc
#     Extracted 13 time steps for rain 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2002_monthly.nc
#     Extracted 13 time steps for rain 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2003_monthly.nc
#     Extracted 13 time steps for rain 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2004_monthly.nc
#     Extracted 13 time steps for rain 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2005_monthly.nc
#     Extracted 13 time steps for rain 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2006_monthly.nc
#     Extracted 13 time steps for rain 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2007_monthly.nc
#     Extracted 13 time steps for rain 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2008_monthly.nc
#     Extracted 13 time steps for rain 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2009_monthly.nc
#     Extracted 13 time steps for rain 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2010_monthly.nc
#     Extracted 13 time steps for rain 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2011_monthly.nc
#     Extracted 13 time steps for rain 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2012_monthly.nc
#     Extracted 13 time steps for rain 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2013_monthly.nc
#     Extracted 13 time steps for rain 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2014_monthly.nc
#     Extracted 13 time steps for rain 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2015_monthly.nc
#     Extracted 13 time steps for rain 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2016_monthly.nc
#     Extracted 13 time steps for rain 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2017_monthly.nc
#     Extracted 13 time steps for rain 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2018_monthly.nc
#     Extracted 13 time steps for rain 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2019_monthly.nc
#     Extracted 13 time steps for rain 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-rain-Europe-2020_monthly.nc
#     Extracted 13 time steps for rain 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2001_monthly.nc
#     Extracted 13 time steps for Rn 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2002_monthly.nc
#     Extracted 13 time steps for Rn 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2003_monthly.nc
#     Extracted 13 time steps for Rn 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2004_monthly.nc
#     Extracted 13 time steps for Rn 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2005_monthly.nc
#     Extracted 13 time steps for Rn 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2006_monthly.nc
#     Extracted 13 time steps for Rn 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2007_monthly.nc
#     Extracted 13 time steps for Rn 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2008_monthly.nc
#     Extracted 13 time steps for Rn 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2009_monthly.nc
#     Extracted 13 time steps for Rn 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2010_monthly.nc
#     Extracted 13 time steps for Rn 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2011_monthly.nc
#     Extracted 13 time steps for Rn 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2012_monthly.nc
#     Extracted 13 time steps for Rn 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2013_monthly.nc
#     Extracted 13 time steps for Rn 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2014_monthly.nc
#     Extracted 13 time steps for Rn 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2015_monthly.nc
#     Extracted 13 time steps for Rn 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2016_monthly.nc
#     Extracted 13 time steps for Rn 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2017_monthly.nc
#     Extracted 13 time steps for Rn 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2018_monthly.nc
#     Extracted 13 time steps for Rn 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2019_monthly.nc
#     Extracted 13 time steps for Rn 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Rn-Europe-2020_monthly.nc
#     Extracted 13 time steps for Rn 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm1 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm1 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm1 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm1 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm1 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm1 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm1 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm1 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm1 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm1 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm1 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm1 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm1 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm1 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm1 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm1 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm1 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm1 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm1 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm1-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm1 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm2 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm2 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm2 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm2 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm2 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm2 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm2 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm2 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm2 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm2 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm2 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm2 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm2 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm2 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm2 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm2 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm2 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm2 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm2 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm2-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm2 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm3 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm3 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm3 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm3 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm3 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm3 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm3 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm3 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm3 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm3 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm3 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm3 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm3 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm3 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm3 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm3 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm3 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm3 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm3 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm3-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm3 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm4 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm4 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm4 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm4 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm4 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm4 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm4 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm4 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm4 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm4 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm4 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm4 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm4 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm4 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm4 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm4 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm4 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm4 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm4 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm4-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm4 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm5 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm5 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm5 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm5 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm5 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm5 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm5 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm5 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm5 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm5 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm5 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm5 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm5 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm5 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm5 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm5 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm5 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm5 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm5 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-sm5-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm5 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ta 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ta 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ta 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ta 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2005_monthly.nc
#     Extracted 13 time steps for Ta 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2006_monthly.nc
#     Extracted 13 time steps for Ta 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2007_monthly.nc
#     Extracted 13 time steps for Ta 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2008_monthly.nc
#     Extracted 13 time steps for Ta 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2009_monthly.nc
#     Extracted 13 time steps for Ta 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2010_monthly.nc
#     Extracted 13 time steps for Ta 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2011_monthly.nc
#     Extracted 13 time steps for Ta 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2012_monthly.nc
#     Extracted 13 time steps for Ta 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2013_monthly.nc
#     Extracted 13 time steps for Ta 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2014_monthly.nc
#     Extracted 13 time steps for Ta 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2015_monthly.nc
#     Extracted 13 time steps for Ta 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2016_monthly.nc
#     Extracted 13 time steps for Ta 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2017_monthly.nc
#     Extracted 13 time steps for Ta 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2018_monthly.nc
#     Extracted 13 time steps for Ta 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2019_monthly.nc
#     Extracted 13 time steps for Ta 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ta-Europe-2020_monthly.nc
#     Extracted 13 time steps for Ta 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2001_monthly.nc
#     Extracted 13 time steps for Td 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2002_monthly.nc
#     Extracted 13 time steps for Td 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2003_monthly.nc
#     Extracted 13 time steps for Td 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2004_monthly.nc
#     Extracted 13 time steps for Td 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2005_monthly.nc
#     Extracted 13 time steps for Td 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2006_monthly.nc
#     Extracted 13 time steps for Td 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2007_monthly.nc
#     Extracted 13 time steps for Td 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2008_monthly.nc
#     Extracted 13 time steps for Td 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2009_monthly.nc
#     Extracted 13 time steps for Td 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2010_monthly.nc
#     Extracted 13 time steps for Td 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2011_monthly.nc
#     Extracted 13 time steps for Td 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2012_monthly.nc
#     Extracted 13 time steps for Td 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2013_monthly.nc
#     Extracted 13 time steps for Td 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2014_monthly.nc
#     Extracted 13 time steps for Td 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2015_monthly.nc
#     Extracted 13 time steps for Td 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2016_monthly.nc
#     Extracted 13 time steps for Td 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2017_monthly.nc
#     Extracted 13 time steps for Td 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2018_monthly.nc
#     Extracted 13 time steps for Td 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2019_monthly.nc
#     Extracted 13 time steps for Td 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Td-Europe-2020_monthly.nc
#     Extracted 13 time steps for Td 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ts 2001
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ts 2002
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ts 2003
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ts 2004
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2005_monthly.nc
#     Extracted 13 time steps for Ts 2005
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2006_monthly.nc
#     Extracted 13 time steps for Ts 2006
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2007_monthly.nc
#     Extracted 13 time steps for Ts 2007
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2008_monthly.nc
#     Extracted 13 time steps for Ts 2008
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2009_monthly.nc
#     Extracted 13 time steps for Ts 2009
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2010_monthly.nc
#     Extracted 13 time steps for Ts 2010
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2011_monthly.nc
#     Extracted 13 time steps for Ts 2011
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2012_monthly.nc
#     Extracted 13 time steps for Ts 2012
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2013_monthly.nc
#     Extracted 13 time steps for Ts 2013
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2014_monthly.nc
#     Extracted 13 time steps for Ts 2014
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2015_monthly.nc
#     Extracted 13 time steps for Ts 2015
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2016_monthly.nc
#     Extracted 13 time steps for Ts 2016
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2017_monthly.nc
#     Extracted 13 time steps for Ts 2017
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2018_monthly.nc
#     Extracted 13 time steps for Ts 2018
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2019_monthly.nc
#     Extracted 13 time steps for Ts 2019
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
#   Reading HOLAPS-Ts-Europe-2020_monthly.nc
#     Extracted 13 time steps for Ts 2020
#     Model grid: (47.1000, 11.3069), Distance: 0.0211°
# ✓ Saved: station_data2\AT-Neu_all_variables.csv with 240 records
#   Years: 20 (2001-2020)
#   Variables: ['GHF', 'H', 'LE', 'Rn', 'Ta', 'Td', 'Ts', 'rain', 'sm1', 'sm2', 'sm3', 'sm4', 'sm5']
#   Avg grid distance: 0.0211°
#
# Processing station: BE-Bra
#   Found 260 NetCDF files
#   Reading HOLAPS-GHF-Europe-2001_monthly.nc
#     Extracted 13 time steps for GHF 2001
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2002_monthly.nc
#     Extracted 13 time steps for GHF 2002
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2003_monthly.nc
#     Extracted 13 time steps for GHF 2003
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2004_monthly.nc
#     Extracted 13 time steps for GHF 2004
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2005_monthly.nc
#     Extracted 13 time steps for GHF 2005
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2006_monthly.nc
#     Extracted 13 time steps for GHF 2006
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2007_monthly.nc
#     Extracted 13 time steps for GHF 2007
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2008_monthly.nc
#     Extracted 13 time steps for GHF 2008
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2009_monthly.nc
#     Extracted 13 time steps for GHF 2009
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2010_monthly.nc
#     Extracted 13 time steps for GHF 2010
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2011_monthly.nc
#     Extracted 13 time steps for GHF 2011
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2012_monthly.nc
#     Extracted 13 time steps for GHF 2012
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2013_monthly.nc
#     Extracted 13 time steps for GHF 2013
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2014_monthly.nc
#     Extracted 13 time steps for GHF 2014
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2015_monthly.nc
#     Extracted 13 time steps for GHF 2015
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2016_monthly.nc
#     Extracted 13 time steps for GHF 2016
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2017_monthly.nc
#     Extracted 13 time steps for GHF 2017
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2018_monthly.nc
#     Extracted 13 time steps for GHF 2018
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2019_monthly.nc
#     Extracted 13 time steps for GHF 2019
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-GHF-Europe-2020_monthly.nc
#     Extracted 13 time steps for GHF 2020
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2001_monthly.nc
#     Extracted 13 time steps for H 2001
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2002_monthly.nc
#     Extracted 13 time steps for H 2002
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2003_monthly.nc
#     Extracted 13 time steps for H 2003
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2004_monthly.nc
#     Extracted 13 time steps for H 2004
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2005_monthly.nc
#     Extracted 13 time steps for H 2005
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2006_monthly.nc
#     Extracted 13 time steps for H 2006
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2007_monthly.nc
#     Extracted 13 time steps for H 2007
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2008_monthly.nc
#     Extracted 13 time steps for H 2008
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2009_monthly.nc
#     Extracted 13 time steps for H 2009
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2010_monthly.nc
#     Extracted 13 time steps for H 2010
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2011_monthly.nc
#     Extracted 13 time steps for H 2011
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2012_monthly.nc
#     Extracted 13 time steps for H 2012
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2013_monthly.nc
#     Extracted 13 time steps for H 2013
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2014_monthly.nc
#     Extracted 13 time steps for H 2014
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2015_monthly.nc
#     Extracted 13 time steps for H 2015
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2016_monthly.nc
#     Extracted 13 time steps for H 2016
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2017_monthly.nc
#     Extracted 13 time steps for H 2017
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2018_monthly.nc
#     Extracted 13 time steps for H 2018
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2019_monthly.nc
#     Extracted 13 time steps for H 2019
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-H-Europe-2020_monthly.nc
#     Extracted 13 time steps for H 2020
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2001_monthly.nc
#     Extracted 13 time steps for LE 2001
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2002_monthly.nc
#     Extracted 13 time steps for LE 2002
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2003_monthly.nc
#     Extracted 13 time steps for LE 2003
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2004_monthly.nc
#     Extracted 13 time steps for LE 2004
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2005_monthly.nc
#     Extracted 13 time steps for LE 2005
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2006_monthly.nc
#     Extracted 13 time steps for LE 2006
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2007_monthly.nc
#     Extracted 13 time steps for LE 2007
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2008_monthly.nc
#     Extracted 13 time steps for LE 2008
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2009_monthly.nc
#     Extracted 13 time steps for LE 2009
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2010_monthly.nc
#     Extracted 13 time steps for LE 2010
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2011_monthly.nc
#     Extracted 13 time steps for LE 2011
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2012_monthly.nc
#     Extracted 13 time steps for LE 2012
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2013_monthly.nc
#     Extracted 13 time steps for LE 2013
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2014_monthly.nc
#     Extracted 13 time steps for LE 2014
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2015_monthly.nc
#     Extracted 13 time steps for LE 2015
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2016_monthly.nc
#     Extracted 13 time steps for LE 2016
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2017_monthly.nc
#     Extracted 13 time steps for LE 2017
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2018_monthly.nc
#     Extracted 13 time steps for LE 2018
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2019_monthly.nc
#     Extracted 13 time steps for LE 2019
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-LE-Europe-2020_monthly.nc
#     Extracted 13 time steps for LE 2020
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2001_monthly.nc
#     Extracted 13 time steps for rain 2001
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2002_monthly.nc
#     Extracted 13 time steps for rain 2002
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2003_monthly.nc
#     Extracted 13 time steps for rain 2003
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2004_monthly.nc
#     Extracted 13 time steps for rain 2004
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2005_monthly.nc
#     Extracted 13 time steps for rain 2005
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2006_monthly.nc
#     Extracted 13 time steps for rain 2006
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2007_monthly.nc
#     Extracted 13 time steps for rain 2007
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2008_monthly.nc
#     Extracted 13 time steps for rain 2008
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2009_monthly.nc
#     Extracted 13 time steps for rain 2009
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2010_monthly.nc
#     Extracted 13 time steps for rain 2010
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2011_monthly.nc
#     Extracted 13 time steps for rain 2011
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2012_monthly.nc
#     Extracted 13 time steps for rain 2012
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2013_monthly.nc
#     Extracted 13 time steps for rain 2013
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2014_monthly.nc
#     Extracted 13 time steps for rain 2014
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2015_monthly.nc
#     Extracted 13 time steps for rain 2015
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2016_monthly.nc
#     Extracted 13 time steps for rain 2016
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2017_monthly.nc
#     Extracted 13 time steps for rain 2017
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2018_monthly.nc
#     Extracted 13 time steps for rain 2018
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2019_monthly.nc
#     Extracted 13 time steps for rain 2019
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-rain-Europe-2020_monthly.nc
#     Extracted 13 time steps for rain 2020
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-Rn-Europe-2001_monthly.nc
#     Extracted 13 time steps for Rn 2001
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-Rn-Europe-2002_monthly.nc
#     Extracted 13 time steps for Rn 2002
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-Rn-Europe-2003_monthly.nc
#     Extracted 13 time steps for Rn 2003
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-Rn-Europe-2004_monthly.nc
#     Extracted 13 time steps for Rn 2004
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-Rn-Europe-2005_monthly.nc
#     Extracted 13 time steps for Rn 2005
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
#   Reading HOLAPS-Rn-Europe-2006_monthly.nc
#     Extracted 13 time steps for Rn 2006
#     Model grid: (51.3000, 4.5164), Distance: 0.0084°
# ...
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm3 2007
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm3 2008
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm3 2009
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm3 2010
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm3 2011
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm3 2012
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm3 2013
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm3 2014
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm3 2015
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm3 2016
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm3 2017
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm3 2018
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm3 2019
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm3-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm3 2020
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm4 2001
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm4 2002
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm4 2003
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm4 2004
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm4 2005
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm4 2006
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm4 2007
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm4 2008
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm4 2009
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm4 2010
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm4 2011
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm4 2012
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm4 2013
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm4 2014
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm4 2015
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm4 2016
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm4 2017
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm4 2018
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm4 2019
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm4-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm4 2020
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2001_monthly.nc
#     Extracted 13 time steps for sm5 2001
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2002_monthly.nc
#     Extracted 13 time steps for sm5 2002
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2003_monthly.nc
#     Extracted 13 time steps for sm5 2003
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2004_monthly.nc
#     Extracted 13 time steps for sm5 2004
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2005_monthly.nc
#     Extracted 13 time steps for sm5 2005
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2006_monthly.nc
#     Extracted 13 time steps for sm5 2006
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2007_monthly.nc
#     Extracted 13 time steps for sm5 2007
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2008_monthly.nc
#     Extracted 13 time steps for sm5 2008
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2009_monthly.nc
#     Extracted 13 time steps for sm5 2009
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2010_monthly.nc
#     Extracted 13 time steps for sm5 2010
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2011_monthly.nc
#     Extracted 13 time steps for sm5 2011
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2012_monthly.nc
#     Extracted 13 time steps for sm5 2012
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2013_monthly.nc
#     Extracted 13 time steps for sm5 2013
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2014_monthly.nc
#     Extracted 13 time steps for sm5 2014
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2015_monthly.nc
#     Extracted 13 time steps for sm5 2015
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2016_monthly.nc
#     Extracted 13 time steps for sm5 2016
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2017_monthly.nc
#     Extracted 13 time steps for sm5 2017
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2018_monthly.nc
#     Extracted 13 time steps for sm5 2018
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2019_monthly.nc
#     Extracted 13 time steps for sm5 2019
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-sm5-Europe-2020_monthly.nc
#     Extracted 13 time steps for sm5 2020
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ta 2001
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ta 2002
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ta 2003
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ta 2004
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2005_monthly.nc
#     Extracted 13 time steps for Ta 2005
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2006_monthly.nc
#     Extracted 13 time steps for Ta 2006
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2007_monthly.nc
#     Extracted 13 time steps for Ta 2007
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2008_monthly.nc
#     Extracted 13 time steps for Ta 2008
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2009_monthly.nc
#     Extracted 13 time steps for Ta 2009
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2010_monthly.nc
#     Extracted 13 time steps for Ta 2010
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2011_monthly.nc
#     Extracted 13 time steps for Ta 2011
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2012_monthly.nc
#     Extracted 13 time steps for Ta 2012
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2013_monthly.nc
#     Extracted 13 time steps for Ta 2013
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2014_monthly.nc
#     Extracted 13 time steps for Ta 2014
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2015_monthly.nc
#     Extracted 13 time steps for Ta 2015
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2016_monthly.nc
#     Extracted 13 time steps for Ta 2016
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2017_monthly.nc
#     Extracted 13 time steps for Ta 2017
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2018_monthly.nc
#     Extracted 13 time steps for Ta 2018
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2019_monthly.nc
#     Extracted 13 time steps for Ta 2019
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ta-Europe-2020_monthly.nc
#     Extracted 13 time steps for Ta 2020
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2001_monthly.nc
#     Extracted 13 time steps for Td 2001
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2002_monthly.nc
#     Extracted 13 time steps for Td 2002
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2003_monthly.nc
#     Extracted 13 time steps for Td 2003
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2004_monthly.nc
#     Extracted 13 time steps for Td 2004
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2005_monthly.nc
#     Extracted 13 time steps for Td 2005
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2006_monthly.nc
#     Extracted 13 time steps for Td 2006
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2007_monthly.nc
#     Extracted 13 time steps for Td 2007
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2008_monthly.nc
#     Extracted 13 time steps for Td 2008
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2009_monthly.nc
#     Extracted 13 time steps for Td 2009
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2010_monthly.nc
#     Extracted 13 time steps for Td 2010
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2011_monthly.nc
#     Extracted 13 time steps for Td 2011
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2012_monthly.nc
#     Extracted 13 time steps for Td 2012
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2013_monthly.nc
#     Extracted 13 time steps for Td 2013
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2014_monthly.nc
#     Extracted 13 time steps for Td 2014
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2015_monthly.nc
#     Extracted 13 time steps for Td 2015
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2016_monthly.nc
#     Extracted 13 time steps for Td 2016
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2017_monthly.nc
#     Extracted 13 time steps for Td 2017
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2018_monthly.nc
#     Extracted 13 time steps for Td 2018
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2019_monthly.nc
#     Extracted 13 time steps for Td 2019
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Td-Europe-2020_monthly.nc
#     Extracted 13 time steps for Td 2020
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2001_monthly.nc
#     Extracted 13 time steps for Ts 2001
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2002_monthly.nc
#     Extracted 13 time steps for Ts 2002
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2003_monthly.nc
#     Extracted 13 time steps for Ts 2003
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2004_monthly.nc
#     Extracted 13 time steps for Ts 2004
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2005_monthly.nc
#     Extracted 13 time steps for Ts 2005
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2006_monthly.nc
#     Extracted 13 time steps for Ts 2006
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2007_monthly.nc
#     Extracted 13 time steps for Ts 2007
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2008_monthly.nc
#     Extracted 13 time steps for Ts 2008
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2009_monthly.nc
#     Extracted 13 time steps for Ts 2009
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2010_monthly.nc
#     Extracted 13 time steps for Ts 2010
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2011_monthly.nc
#     Extracted 13 time steps for Ts 2011
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2012_monthly.nc
#     Extracted 13 time steps for Ts 2012
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2013_monthly.nc
#     Extracted 13 time steps for Ts 2013
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2014_monthly.nc
#     Extracted 13 time steps for Ts 2014
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2015_monthly.nc
#     Extracted 13 time steps for Ts 2015
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2016_monthly.nc
#     Extracted 13 time steps for Ts 2016
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2017_monthly.nc
#     Extracted 13 time steps for Ts 2017
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2018_monthly.nc
#     Extracted 13 time steps for Ts 2018
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2019_monthly.nc
#     Extracted 13 time steps for Ts 2019
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
#   Reading HOLAPS-Ts-Europe-2020_monthly.nc
#     Extracted 13 time steps for Ts 2020
#     Model grid: (56.4500, 32.9359), Distance: 0.0180°
# ✓ Saved: station_data2\RU-Fyo_all_variables.csv with 240 records
#   Years: 20 (2001-2020)
#   Variables: ['GHF', 'H', 'LE', 'Rn', 'Ta', 'Td', 'Ts', 'rain', 'sm1', 'sm2', 'sm3', 'sm4', 'sm5']
#   Avg grid distance: 0.0180°
